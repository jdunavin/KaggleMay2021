# %% [markdown]
# # Kaggle May 2021 monthly challenge
# This notebook was built to explore the Kaggle May 2021 monthly challenge.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %% [markdown]
# ## The rundown
# There are 50 features - we don't know exactly what they represent. They are used to predict belonging to one of four classes. We need to predict the likelihood of belonging to each.
#
# There are 100,000 rows in the training dataset and 50,000 in the test set.

# %% [markdown]
# ## Load the data
# We'll load training data and examine the class/feature relationships. Then we'll load the test data, and glue the two together to examine them. We'll also get rid of the 'id' column, since it isn't necessary.

# %%
train_all = pd.read_csv('~/Data/Kaggle/May2021/train.csv') 
test_X = pd.read_csv('~/Data/Kaggle/May2021/test.csv')

# %%
train_y = train_all['target']
train_y_num = [int(x[-1]) for x in train_y] # Keep just the integer description

# %%
train_X = train_all.drop('id', axis=1)
test_X = test_X.drop('id', axis=1)

# %% [markdown]
# ## Investigate the data

# %%
# Are there any missing values for features?
test_X.describe().T.style.bar(subset=['mean'], color='#205ff2')\
                            .background_gradient(subset=['std'], cmap='Reds')\
                            .background_gradient(subset=['50%'], cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_0ad0a_row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 6.1%, transparent 6.1%);
#         }#T_0ad0a_row0_col2{
#             background-color:  #fee3d6;
#             color:  #000000;
#         }#T_0ad0a_row0_col5,#T_0ad0a_row1_col5,#T_0ad0a_row2_col5,#T_0ad0a_row3_col5,#T_0ad0a_row4_col5,#T_0ad0a_row5_col5,#T_0ad0a_row6_col5,#T_0ad0a_row7_col5,#T_0ad0a_row8_col5,#T_0ad0a_row9_col5,#T_0ad0a_row10_col5,#T_0ad0a_row11_col5,#T_0ad0a_row12_col5,#T_0ad0a_row13_col5,#T_0ad0a_row15_col5,#T_0ad0a_row16_col5,#T_0ad0a_row17_col5,#T_0ad0a_row18_col5,#T_0ad0a_row19_col5,#T_0ad0a_row20_col5,#T_0ad0a_row21_col5,#T_0ad0a_row22_col5,#T_0ad0a_row23_col5,#T_0ad0a_row24_col5,#T_0ad0a_row25_col5,#T_0ad0a_row26_col5,#T_0ad0a_row27_col5,#T_0ad0a_row28_col5,#T_0ad0a_row29_col5,#T_0ad0a_row30_col5,#T_0ad0a_row31_col5,#T_0ad0a_row32_col5,#T_0ad0a_row33_col5,#T_0ad0a_row34_col5,#T_0ad0a_row35_col5,#T_0ad0a_row36_col5,#T_0ad0a_row37_col5,#T_0ad0a_row39_col5,#T_0ad0a_row40_col5,#T_0ad0a_row41_col5,#T_0ad0a_row42_col5,#T_0ad0a_row43_col5,#T_0ad0a_row44_col5,#T_0ad0a_row45_col5,#T_0ad0a_row46_col5,#T_0ad0a_row47_col5,#T_0ad0a_row48_col5,#T_0ad0a_row49_col5{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_0ad0a_row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 12.6%, transparent 12.6%);
#         }#T_0ad0a_row1_col2{
#             background-color:  #fca183;
#             color:  #000000;
#         }#T_0ad0a_row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 1.4%, transparent 1.4%);
#         }#T_0ad0a_row2_col2{
#             background-color:  #fff0e8;
#             color:  #000000;
#         }#T_0ad0a_row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 17.4%, transparent 17.4%);
#         }#T_0ad0a_row3_col2{
#             background-color:  #fcae92;
#             color:  #000000;
#         }#T_0ad0a_row4_col1,#T_0ad0a_row43_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 18.4%, transparent 18.4%);
#         }#T_0ad0a_row4_col2{
#             background-color:  #fb6c4c;
#             color:  #000000;
#         }#T_0ad0a_row5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 2.9%, transparent 2.9%);
#         }#T_0ad0a_row5_col2{
#             background-color:  #ffede5;
#             color:  #000000;
#         }#T_0ad0a_row6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 23.0%, transparent 23.0%);
#         }#T_0ad0a_row6_col2,#T_0ad0a_row42_col2{
#             background-color:  #fc8a6a;
#             color:  #000000;
#         }#T_0ad0a_row7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 39.8%, transparent 39.8%);
#         }#T_0ad0a_row7_col2{
#             background-color:  #fb7252;
#             color:  #000000;
#         }#T_0ad0a_row8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 27.8%, transparent 27.8%);
#         }#T_0ad0a_row8_col2{
#             background-color:  #f14331;
#             color:  #f1f1f1;
#         }#T_0ad0a_row9_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 29.7%, transparent 29.7%);
#         }#T_0ad0a_row9_col2{
#             background-color:  #fca78b;
#             color:  #000000;
#         }#T_0ad0a_row10_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 8.5%, transparent 8.5%);
#         }#T_0ad0a_row10_col2{
#             background-color:  #fed8c7;
#             color:  #000000;
#         }#T_0ad0a_row11_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 11.3%, transparent 11.3%);
#         }#T_0ad0a_row11_col2{
#             background-color:  #fedfd0;
#             color:  #000000;
#         }#T_0ad0a_row12_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 13.4%, transparent 13.4%);
#         }#T_0ad0a_row12_col2{
#             background-color:  #fdd7c6;
#             color:  #000000;
#         }#T_0ad0a_row13_col1{
#             width:  10em;
#              height:  80%;
#         }#T_0ad0a_row13_col2{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_0ad0a_row14_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 86.8%, transparent 86.8%);
#         }#T_0ad0a_row14_col2,#T_0ad0a_row19_col2{
#             background-color:  #ab1016;
#             color:  #f1f1f1;
#         }#T_0ad0a_row14_col5,#T_0ad0a_row38_col5{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_0ad0a_row15_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 40.5%, transparent 40.5%);
#         }#T_0ad0a_row15_col2,#T_0ad0a_row21_col2{
#             background-color:  #fc9777;
#             color:  #000000;
#         }#T_0ad0a_row16_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 9.6%, transparent 9.6%);
#         }#T_0ad0a_row16_col2{
#             background-color:  #fdd1be;
#             color:  #000000;
#         }#T_0ad0a_row17_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 23.3%, transparent 23.3%);
#         }#T_0ad0a_row17_col2{
#             background-color:  #fcab8f;
#             color:  #000000;
#         }#T_0ad0a_row18_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 13.5%, transparent 13.5%);
#         }#T_0ad0a_row18_col2{
#             background-color:  #fedaca;
#             color:  #000000;
#         }#T_0ad0a_row19_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 48.6%, transparent 48.6%);
#         }#T_0ad0a_row20_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 5.7%, transparent 5.7%);
#         }#T_0ad0a_row20_col2{
#             background-color:  #fee2d5;
#             color:  #000000;
#         }#T_0ad0a_row21_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 20.0%, transparent 20.0%);
#         }#T_0ad0a_row22_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 3.8%, transparent 3.8%);
#         }#T_0ad0a_row22_col2{
#             background-color:  #ffeee7;
#             color:  #000000;
#         }#T_0ad0a_row23_col1,#T_0ad0a_row37_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 10.9%, transparent 10.9%);
#         }#T_0ad0a_row23_col2{
#             background-color:  #fdd2bf;
#             color:  #000000;
#         }#T_0ad0a_row24_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 33.1%, transparent 33.1%);
#         }#T_0ad0a_row24_col2{
#             background-color:  #fc7f5f;
#             color:  #000000;
#         }#T_0ad0a_row25_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 11.4%, transparent 11.4%);
#         }#T_0ad0a_row25_col2{
#             background-color:  #fdccb8;
#             color:  #000000;
#         }#T_0ad0a_row26_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 10.3%, transparent 10.3%);
#         }#T_0ad0a_ro

# %%
train_X.describe().T.style.bar(subset=['mean'], color='#205ff2')\
                            .background_gradient(subset=['std'], cmap='Reds')\
                            .background_gradient(subset=['50%'], cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_b7e0d_row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 6.2%, transparent 6.2%);
#         }#T_b7e0d_row0_col2{
#             background-color:  #fee2d5;
#             color:  #000000;
#         }#T_b7e0d_row0_col5,#T_b7e0d_row1_col5,#T_b7e0d_row2_col5,#T_b7e0d_row3_col5,#T_b7e0d_row4_col5,#T_b7e0d_row5_col5,#T_b7e0d_row6_col5,#T_b7e0d_row7_col5,#T_b7e0d_row8_col5,#T_b7e0d_row9_col5,#T_b7e0d_row10_col5,#T_b7e0d_row11_col5,#T_b7e0d_row12_col5,#T_b7e0d_row13_col5,#T_b7e0d_row15_col5,#T_b7e0d_row16_col5,#T_b7e0d_row17_col5,#T_b7e0d_row18_col5,#T_b7e0d_row19_col5,#T_b7e0d_row20_col5,#T_b7e0d_row21_col5,#T_b7e0d_row22_col5,#T_b7e0d_row23_col5,#T_b7e0d_row24_col5,#T_b7e0d_row25_col5,#T_b7e0d_row26_col5,#T_b7e0d_row27_col5,#T_b7e0d_row28_col5,#T_b7e0d_row29_col5,#T_b7e0d_row30_col5,#T_b7e0d_row31_col5,#T_b7e0d_row32_col5,#T_b7e0d_row33_col5,#T_b7e0d_row34_col5,#T_b7e0d_row35_col5,#T_b7e0d_row36_col5,#T_b7e0d_row37_col5,#T_b7e0d_row39_col5,#T_b7e0d_row40_col5,#T_b7e0d_row41_col5,#T_b7e0d_row42_col5,#T_b7e0d_row43_col5,#T_b7e0d_row44_col5,#T_b7e0d_row45_col5,#T_b7e0d_row46_col5,#T_b7e0d_row47_col5,#T_b7e0d_row48_col5,#T_b7e0d_row49_col5{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_b7e0d_row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 12.2%, transparent 12.2%);
#         }#T_b7e0d_row1_col2{
#             background-color:  #fca486;
#             color:  #000000;
#         }#T_b7e0d_row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 1.3%, transparent 1.3%);
#         }#T_b7e0d_row2_col2{
#             background-color:  #fff0e8;
#             color:  #000000;
#         }#T_b7e0d_row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 17.6%, transparent 17.6%);
#         }#T_b7e0d_row3_col2{
#             background-color:  #fcad90;
#             color:  #000000;
#         }#T_b7e0d_row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 17.9%, transparent 17.9%);
#         }#T_b7e0d_row4_col2{
#             background-color:  #fb7050;
#             color:  #000000;
#         }#T_b7e0d_row5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 2.9%, transparent 2.9%);
#         }#T_b7e0d_row5_col2{
#             background-color:  #ffede5;
#             color:  #000000;
#         }#T_b7e0d_row6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 22.4%, transparent 22.4%);
#         }#T_b7e0d_row6_col2,#T_b7e0d_row43_col2{
#             background-color:  #fc8b6b;
#             color:  #000000;
#         }#T_b7e0d_row7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 39.5%, transparent 39.5%);
#         }#T_b7e0d_row7_col2{
#             background-color:  #fb7656;
#             color:  #000000;
#         }#T_b7e0d_row8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 28.3%, transparent 28.3%);
#         }#T_b7e0d_row8_col2{
#             background-color:  #f14130;
#             color:  #f1f1f1;
#         }#T_b7e0d_row9_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 29.6%, transparent 29.6%);
#         }#T_b7e0d_row9_col2{
#             background-color:  #fca98c;
#             color:  #000000;
#         }#T_b7e0d_row10_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 8.1%, transparent 8.1%);
#         }#T_b7e0d_row10_col2{
#             background-color:  #fed9c9;
#             color:  #000000;
#         }#T_b7e0d_row11_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 11.2%, transparent 11.2%);
#         }#T_b7e0d_row11_col2{
#             background-color:  #fedfd0;
#             color:  #000000;
#         }#T_b7e0d_row12_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 13.2%, transparent 13.2%);
#         }#T_b7e0d_row12_col2{
#             background-color:  #fed8c7;
#             color:  #000000;
#         }#T_b7e0d_row13_col1{
#             width:  10em;
#              height:  80%;
#         }#T_b7e0d_row13_col2{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_b7e0d_row14_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 86.3%, transparent 86.3%);
#         }#T_b7e0d_row14_col2{
#             background-color:  #ab1016;
#             color:  #f1f1f1;
#         }#T_b7e0d_row14_col5,#T_b7e0d_row38_col5{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_b7e0d_row15_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 39.9%, transparent 39.9%);
#         }#T_b7e0d_row15_col2{
#             background-color:  #fc9879;
#             color:  #000000;
#         }#T_b7e0d_row16_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 9.9%, transparent 9.9%);
#         }#T_b7e0d_row16_col2{
#             background-color:  #fdcebb;
#             color:  #000000;
#         }#T_b7e0d_row17_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 22.7%, transparent 22.7%);
#         }#T_b7e0d_row17_col2{
#             background-color:  #fcae92;
#             color:  #000000;
#         }#T_b7e0d_row18_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 13.5%, transparent 13.5%);
#         }#T_b7e0d_row18_col2,#T_b7e0d_row37_col2{
#             background-color:  #fedaca;
#             color:  #000000;
#         }#T_b7e0d_row19_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 51.0%, transparent 51.0%);
#         }#T_b7e0d_row19_col2{
#             background-color:  #a50f15;
#             color:  #f1f1f1;
#         }#T_b7e0d_row20_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 5.7%, transparent 5.7%);
#         }#T_b7e0d_row20_col2{
#             background-color:  #fee3d6;
#             color:  #000000;
#         }#T_b7e0d_row21_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 20.1%, transparent 20.1%);
#         }#T_b7e0d_row21_col2,#T_b7e0d_row46_col2{
#             background-color:  #fc9777;
#             color:  #000000;
#         }#T_b7e0d_row22_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 3.7%, transparent 3.7%);
#         }#T_b7e0d_row22_col2{
#             background-color:  #ffefe8;
#             color:  #000000;
#         }#T_b7e0d_row23_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 10.7%, transparent 10.7%);
#         }#T_b7e0d_row23_col2{
#             background-color:  #fdd3c1;
#             color:  #000000;
#         }#T_b7e0d_row24_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 33.0%, transparent 33.0%);
#         }#T_b7e0d_row24_col2{
#             background-color:  #fc7f5f;
#             color:  #000000;
#         }#T_b7e0d_row25_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 11.4%, transparent 11.4%);
#         }#T_b7e0d_row25_col2{
#             background-color:  #fdccb8;
#             color:  #000000;
#         }#T_b7e0d_row26_col

# %%
data_X.describe().T.style.bar(subset=['mean'], color='#205ff2')\
                            .background_gradient(subset=['std'], cmap='Reds')\
                            .background_gradient(subset=['50%'], cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_11d27_row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 6.2%, transparent 6.2%);
#         }#T_11d27_row0_col2{
#             background-color:  #fee3d6;
#             color:  #000000;
#         }#T_11d27_row0_col5,#T_11d27_row1_col5,#T_11d27_row2_col5,#T_11d27_row3_col5,#T_11d27_row4_col5,#T_11d27_row5_col5,#T_11d27_row6_col5,#T_11d27_row7_col5,#T_11d27_row8_col5,#T_11d27_row9_col5,#T_11d27_row10_col5,#T_11d27_row11_col5,#T_11d27_row12_col5,#T_11d27_row13_col5,#T_11d27_row15_col5,#T_11d27_row16_col5,#T_11d27_row17_col5,#T_11d27_row18_col5,#T_11d27_row19_col5,#T_11d27_row20_col5,#T_11d27_row21_col5,#T_11d27_row22_col5,#T_11d27_row23_col5,#T_11d27_row24_col5,#T_11d27_row25_col5,#T_11d27_row26_col5,#T_11d27_row27_col5,#T_11d27_row28_col5,#T_11d27_row29_col5,#T_11d27_row30_col5,#T_11d27_row31_col5,#T_11d27_row32_col5,#T_11d27_row33_col5,#T_11d27_row34_col5,#T_11d27_row35_col5,#T_11d27_row36_col5,#T_11d27_row37_col5,#T_11d27_row39_col5,#T_11d27_row40_col5,#T_11d27_row41_col5,#T_11d27_row42_col5,#T_11d27_row43_col5,#T_11d27_row44_col5,#T_11d27_row45_col5,#T_11d27_row46_col5,#T_11d27_row47_col5,#T_11d27_row48_col5,#T_11d27_row49_col5{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_11d27_row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 12.3%, transparent 12.3%);
#         }#T_11d27_row1_col2{
#             background-color:  #fca285;
#             color:  #000000;
#         }#T_11d27_row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 1.3%, transparent 1.3%);
#         }#T_11d27_row2_col2{
#             background-color:  #fff0e8;
#             color:  #000000;
#         }#T_11d27_row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 17.6%, transparent 17.6%);
#         }#T_11d27_row3_col2,#T_11d27_row17_col2{
#             background-color:  #fcad90;
#             color:  #000000;
#         }#T_11d27_row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 18.1%, transparent 18.1%);
#         }#T_11d27_row4_col2{
#             background-color:  #fb6e4e;
#             color:  #000000;
#         }#T_11d27_row5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 2.9%, transparent 2.9%);
#         }#T_11d27_row5_col2{
#             background-color:  #ffede5;
#             color:  #000000;
#         }#T_11d27_row6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 22.6%, transparent 22.6%);
#         }#T_11d27_row6_col2,#T_11d27_row43_col2{
#             background-color:  #fc8b6b;
#             color:  #000000;
#         }#T_11d27_row7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 39.6%, transparent 39.6%);
#         }#T_11d27_row7_col2{
#             background-color:  #fb7555;
#             color:  #000000;
#         }#T_11d27_row8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 28.1%, transparent 28.1%);
#         }#T_11d27_row8_col2{
#             background-color:  #f14130;
#             color:  #f1f1f1;
#         }#T_11d27_row9_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 29.6%, transparent 29.6%);
#         }#T_11d27_row9_col2{
#             background-color:  #fca78b;
#             color:  #000000;
#         }#T_11d27_row10_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 8.2%, transparent 8.2%);
#         }#T_11d27_row10_col2,#T_11d27_row12_col2{
#             background-color:  #fed8c7;
#             color:  #000000;
#         }#T_11d27_row11_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 11.3%, transparent 11.3%);
#         }#T_11d27_row11_col2{
#             background-color:  #fedfd0;
#             color:  #000000;
#         }#T_11d27_row12_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 13.3%, transparent 13.3%);
#         }#T_11d27_row13_col1{
#             width:  10em;
#              height:  80%;
#         }#T_11d27_row13_col2{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_11d27_row14_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 86.5%, transparent 86.5%);
#         }#T_11d27_row14_col2{
#             background-color:  #ab1016;
#             color:  #f1f1f1;
#         }#T_11d27_row14_col5,#T_11d27_row38_col5{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_11d27_row15_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 40.1%, transparent 40.1%);
#         }#T_11d27_row15_col2,#T_11d27_row21_col2,#T_11d27_row46_col2{
#             background-color:  #fc9777;
#             color:  #000000;
#         }#T_11d27_row16_col1,#T_11d27_row26_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 9.8%, transparent 9.8%);
#         }#T_11d27_row16_col2{
#             background-color:  #fdd0bc;
#             color:  #000000;
#         }#T_11d27_row17_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 22.9%, transparent 22.9%);
#         }#T_11d27_row18_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 13.5%, transparent 13.5%);
#         }#T_11d27_row18_col2,#T_11d27_row37_col2{
#             background-color:  #fedaca;
#             color:  #000000;
#         }#T_11d27_row19_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 50.2%, transparent 50.2%);
#         }#T_11d27_row19_col2{
#             background-color:  #a81016;
#             color:  #f1f1f1;
#         }#T_11d27_row20_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 5.7%, transparent 5.7%);
#         }#T_11d27_row20_col2{
#             background-color:  #fee2d5;
#             color:  #000000;
#         }#T_11d27_row21_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 20.0%, transparent 20.0%);
#         }#T_11d27_row22_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 3.8%, transparent 3.8%);
#         }#T_11d27_row22_col2{
#             background-color:  #ffeee7;
#             color:  #000000;
#         }#T_11d27_row23_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 10.8%, transparent 10.8%);
#         }#T_11d27_row23_col2{
#             background-color:  #fdd3c1;
#             color:  #000000;
#         }#T_11d27_row24_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 33.0%, transparent 33.0%);
#         }#T_11d27_row24_col2{
#             background-color:  #fc7f5f;
#             color:  #000000;
#         }#T_11d27_row25_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 11.4%, transparent 11.4%);
#         }#T_11d27_row25_col2{
#             background-color:  #fdccb8;
#             color:  #000000;
#         }#T_11d27_row26_col2{
#             background-color:  #fcc2aa;
#             color:  #000000;
#         }#T_11d27_row27_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 7.7%, t

# %% [markdown]
# From the above, it looks like the features are all heavily skewed toward smaller values. That checks out from the data overview given in the challenge docs. It looks like most of the entries in each feature are 0. Feature 42 had a minimum value of 0 in the training set and -2 in the test set, so we'll see how weird that turns out to be. Otherwise, the summaries of the training and test sets did not reveal any material difference in distribution. However, it does look like there's some differences in the range of some features between the training and test sets, so if we do scaling we might want to combine them first.

# %%
# Any missing values?
missing_vals = data_X.isnull().sum()
missing_vals.sum()
# Nope
# Out:
# 0

# %%
# Any duplicate rows in the training set?
train_X[train_X.drop('target', axis=1).duplicated(keep='first')]
# Out:
#        feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 44423          0          0          0          0          0          0
# 73244          0          0          0          0          0          0
# 80571          0          0          0          0          0          0
# 89009          0          0          0          0          0          0
#
#        feature_6  feature_7  feature_8  feature_9  ...  feature_41  \
# 44423          0          0          0          0  ...           0
# 73244          0          0          0          0  ...           0
# 80571          0          0          0          0  ...           0
# 89009          0          1          0          0  ...           0
#
#        feature_42  feature_43  feature_44  feature_45  feature_46  feature_47  \
# 44423           0           0           0           0           0           0
# 73244           0           0           0           0           0           0
# 80571           0           0           0           0           0           0
# 89009           0           0           0           0           0           0
#
#        feature_48  feature_49   target
# 44423           0           0  Class_4
# 73244           0           0  Class_2
# 80571           0           0  Class_4
# 89009           0           0  Class_1
#
# [4 rows x 51 columns]

# %%
train_X[train_X.drop('target', axis=1).duplicated(keep='last')]
# Out:
#        feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 13230          0          0          0          0          0          0
# 25648          0          0          0          0          0          0
# 44248          0          0          0          0          0          0
# 87104          0          0          0          0          0          0
#
#        feature_6  feature_7  feature_8  feature_9  ...  feature_41  \
# 13230          0          0          0          0  ...           0
# 25648          0          0          0          0  ...           0
# 44248          0          0          0          0  ...           0
# 87104          0          1          0          0  ...           0
#
#        feature_42  feature_43  feature_44  feature_45  feature_46  feature_47  \
# 13230           0           0           0           0           0           0
# 25648           0           0           0           0           0           0
# 44248           0           0           0           0           0           0
# 87104           0           0           0           0           0           0
#
#        feature_48  feature_49   target
# 13230           0           0  Class_2
# 25648           0           0  Class_4
# 44248           0           0  Class_2
# 87104           0           0  Class_3
#
# [4 rows x 51 columns]

# %%
# Need to get rid of these
train_X = train_X.drop([44423, 73244,80571,89009,13230,25648,44248,87104])

# %%
train_y = train_y.drop([44423, 73244,80571,89009,13230,25648,44248,87104])

# %%
# Any training rows that are also in the test set?
data_X = train_X.drop('target',axis=1).append(test_X, ignore_index = True)
data_X[data_X.duplicated(keep='first')]
# Out:
#         feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 101165          0          0          0          0          0          0
# 114762          0          0          0          0          0          0
# 120746          0          0          0          0          0          0
# 132008          0          0          0          0          0          0
# 143128          0          0          0          0          0          0
# 143290          0          0          0          0          0          0
#
#         feature_6  feature_7  feature_8  feature_9  ...  feature_40  \
# 101165          0          0          0          0  ...           0
# 114762          0          0          0          0  ...           0
# 120746          0          0          0          0  ...           0
# 132008          0          0          0          0  ...           0
# 143128          0          0          0          0  ...           0
# 143290          0          0          0          0  ...           0
#
#         feature_41  feature_42  feature_43  feature_44  feature_45  \
# 101165           0           0           0           0           0
# 114762           0           0           0           0           0
# 120746           0           0           0           0           0
# 132008           0           0           0           0           0
# 143128           0           0           0           0           0
# 143290           0           0           0           0           0
#
#         feature_46  feature_47  feature_48  feature_49
# 101165           0           0           0           0
# 114762           0           0           0           0
# 120746           0           0           0           0
# 132008           0           0           0           0
# 143128           0           0           1           0
# 143290           0           0           0           0
#
# [6 rows x 50 columns]

# %%
train_test_dupes = data_X[data_X.duplicated(keep='last')].index
save_preds = train_X.loc[train_test_dupes, 'target']

# %%
# Find the pairs
for i in train_test_dupes:
    for j in data_X[data_X.duplicated(keep='first')].index:
        if data_X.loc[i].equals(data_X.loc[j]):
            print(i,j)
# Out:
# 23271 143290
# 31715 132008
# 36456 143128
# 62186 114762
# 63139 101165
# 81432 120746

# %%
# Hang on to these - we'll force the matching rows in test to these predictions later
save_preds
# Out:
# 23271    Class_2
# 31715    Class_3
# 36456    Class_3
# 62186    Class_4
# 63139    Class_3
# 81432    Class_2
# Name: target, dtype: object

# %% [markdown]
# ## Check pairwise correlations

# %%
datacorr = data_X.corr()
plt.subplots(figsize=(10,10))
sns.heatmap(datacorr)
plt.show()

# %% [markdown]
# It appears that no two columns are correlated. Running `data_X.dtypes` shows that the data are all integers. I was going to look up and research how to do a batch KDE plot of each column, but other contestants have done that, so I shamelessly stole it.

# %% [markdown]
# ### Show disribution of class predictions
# First we'll show the distribution of target classes generally. Then we'll show it with respect to each feature separately.

# %%
fig, ax = plt.subplots(figsize=(9,6))
sns.countplot(data=train_y, x=train_y, order=sorted(train_y.unique()), ax=ax)
ax.set_title("Target distribution", size=16, weight='bold')
plt.show()

# %% [markdown]
# So it seems like you could make a naive predction by just saying everything belongs to Class_2. Or you could assign to each class this relative distribution.

# %% [markdown]
# ### Baseline prediction
# Class 2 probability = 1, all others = 0 for all test rows.

# %%
submission1 = pd.DataFrame(columns=['Class_1','Class_2','Class_3','Class_4'], index=test_X.index+100000)

# %%
submission1.fillna(0.0, inplace=True)
submission1.Class_2 = 1.0
submission1.index.name = 'id'
submission1.head()
# Out:
#         Class_1  Class_2  Class_3  Class_4
# id
# 100000      0.0      1.0      0.0      0.0
# 100001      0.0      1.0      0.0      0.0
# 100002      0.0      1.0      0.0      0.0
# 100003      0.0      1.0      0.0      0.0
# 100004      0.0      1.0      0.0      0.0

# %%
submission1.to_csv('naive_submission.csv', header=True)

# %% [markdown]
# Score was 14.622 - which is pretty bad. That's what I expected. Let's try the other dumb way, which is to assign to each submission column the proportion of each class label in the training set.

# %%
naive2 = train_X['target'].value_counts()/len(train_X)
submission2 = pd.DataFrame(columns=['Class_1','Class_2','Class_3','Class_4'], index=test_X.index+100000)
submission2.Class_1 = naive2.Class_1
submission2.Class_2 = naive2.Class_2
submission2.Class_3 = naive2.Class_3
submission2.Class_4 = naive2.Class_4
submission2.index.name = 'id'
submission2.head()
# Out:
#          Class_1   Class_2   Class_3  Class_4
# id
# 100000  0.084897  0.574986  0.214207  0.12591
# 100001  0.084897  0.574986  0.214207  0.12591
# 100002  0.084897  0.574986  0.214207  0.12591
# 100003  0.084897  0.574986  0.214207  0.12591
# 100004  0.084897  0.574986  0.214207  0.12591

# %%
submission2.to_csv('naive2_submission.csv', header=True)

# %% [markdown]
# Score was 1.11371 which is much better, but still behind the top performers. The difference between me and numero uno right now was 0.04 in public score, and I'm in 545th place.

# %% [markdown]
# ## Continue exploring data

# %%
# Shamelessly stolen from https://www.kaggle.com/subinium/tps-may-categorical-eda
# because I thought it looked cool.
# This is supposed to be a learning exercise for me so I want to document what this does

# Create a set of plots 13 plots tall and 4 plots wide, because we need 50 and 13x4 = 52.
fig, axes = plt.subplots(13, 4, figsize=(10, 16))

# List the classes in the most obvious order
target_order = sorted(train_y.unique())

# Get the mean and std dev of each feature within each class prediction. IE, take all 
# of the 'class 1' rows and get the mean / std dev of each feature.
mean = train_X.groupby('target').mean().sort_index()
std = train_X.groupby('target').std().sort_index()

# For each feature and plot, create a bar plot of the mean as described above. Remove the ticks
# and labels, narrow the margins, put a title in, and hide plots #51 and 52 since they don't really
# exist.
for idx, ax in zip(range(50), axes.flatten()):
    ax.bar(mean[f'feature_{idx}'].index, mean[f'feature_{idx}'], width=0.6)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_xlabel('')
    ax.set_ylabel('')
    ax.margins(0.1)
    ax.spines['left'].set_visible(False)
    ax.set_title(f'Feature_{idx}', loc='right', weight='bold', fontsize=11)

axes.flatten()[-1].axis('off')    
axes.flatten()[-2].axis('off')

fig.supxlabel('Average by class (by feature)', ha='center', fontweight='bold')

fig.tight_layout()
plt.show()

# %%
# Shamelessly stolen from https://www.kaggle.com/subinium/tps-may-categorical-eda
# because I thought it looked cool.
# This is supposed to be a learning exercise for me so I want to document what this does

# Create a set of plots 13 plots tall and 4 plots wide, because we need 50 and 13x4 = 52.
fig, axes = plt.subplots(13, 4, figsize=(10, 16))

# List the classes in the most obvious order
target_order = sorted(train_y.unique())

# Get the mean and std dev of each feature within each class prediction. IE, take all 
# of the 'class 1' rows and get the mean / std dev of each feature.
mean = train_X.groupby('target').mean().sort_index()
std = train_X.groupby('target').std().sort_index()

# For each feature and plot, create a bar plot of the mean as described above. Remove the ticks
# and labels, narrow the margins, put a title in, and hide plots #51 and 52 since they don't really
# exist.
for idx, ax in zip(range(50), axes.flatten()):
    ax.bar(std[f'feature_{idx}'].index, std[f'feature_{idx}'], width=0.6)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_xlabel('')
    ax.set_ylabel('')
    ax.margins(0.1)
    ax.spines['left'].set_visible(False)
    ax.set_title(f'Feature_{idx}', loc='right', weight='bold', fontsize=11)

axes.flatten()[-1].axis('off')    
axes.flatten()[-2].axis('off')

fig.supxlabel('Standard deviation by class (by feature)', ha='center', fontweight='bold')

fig.tight_layout()
plt.show()

# %% [markdown]
# It's clear that there are differences in the mean / standard deviation of many features when calculated with respect to class in the training data. However, it may be that not all features are predictive. Now, what's the total number of values in each column?

# %%
# Again, this is stolen
fig, ax = plt.subplots(1, 1, figsize=(12, 6))

y = np.array([train_X[f'feature_{i}'].nunique() for i in range(50)])
y2 = np.array([test_X[f'feature_{i}'].nunique() for i in range(50)])
comp = y-y2


ax.bar(range(50), y2, alpha=0.7, label='Test Dataset')
ax.bar(range(50),  comp*(comp>0), bottom=y2, alpha=0.7, label='Test > Train')
ax.bar(range(50), comp*(comp<0), bottom=y2-comp*(comp<0), alpha=0.7, label='Test < Train')

ax.set_yticks(range(0, 80, 5))
ax.margins(0.02)
ax.grid(axis='y', linestyle='--', zorder=5)
ax.set_title('# of Features Unique Values (Train/Test)', loc='left', fontweight='bold')
ax.legend()
plt.show()

# %%
categorical_features = data_X.nunique()

# %%
discrete_features = categorical_features <= 12

# %% [markdown]
# ## Mutual information
# I wanted to see the 'mutual information' from the Kaggle courses. In the line just above this we make an assumption about which features are truly categorical and which aren't. We don't know for sure which ones they are, if there are any.

# %%
from sklearn.feature_selection import mutual_info_regression
from sklearn.feature_selection import mutual_info_classif

# %%
def make_mi_scores(X, y, discrete_features):
    mi_scores = mutual_info_classif(X, y, discrete_features=discrete_features)
    mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
    mi_scores = mi_scores.sort_values(ascending=False)
    return mi_scores

mi_scores = make_mi_scores(train_X.drop('target',axis=1), train_y, discrete_features)
mi_scores[::3]  # show a few features with their MI scores
# Out:
# feature_15    0.004153
# feature_14    0.003405
# feature_23    0.002768
# feature_17    0.002703
# feature_25    0.002052
# feature_29    0.001611
# feature_5     0.001281
# feature_40    0.001067
# feature_22    0.000865
# feature_24    0.000810
# feature_7     0.000641
# feature_41    0.000587
# feature_42    0.000466
# feature_18    0.000000
# feature_27    0.000000
# feature_6     0.000000
# feature_26    0.000000
# Name: MI Scores, dtype: float64

# %% [markdown]
# Seems weird to me. Seems like features 10 and 2 (for example) have something to do with Class 3, but they don't show up on this list as contributing significant relationship to the class predictions.

# %% [markdown]
# # XGBoost
# I'm just going to try it with no tuning or messing around whatsoever.

# %%
from xgboost import XGBClassifier

# %%
model1 = XGBClassifier(random_state = 14000605)
model1.fit(train_X.drop('target',axis=1), train_y)
# Out:
# /home/jdunavin/.local/lib/python3.9/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:24:28] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=4, num_parallel_tree=1,
#               objective='multi:softprob', random_state=14000605, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=None, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
preds = model1.predict_proba(test_X)
# Out:
# /home/jdunavin/.local/lib/python3.9/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
submission3 = pd.DataFrame(preds)

# %%
submission3.columns = ['Class_1', 'Class_2','Class_3','Class_4']
submission3.index = range(100000, 150000, 1)
submission3.index.name = 'id'
submission3.head()
# Out:
#          Class_1   Class_2   Class_3   Class_4
# id
# 100000  0.108131  0.496554  0.269379  0.125936
# 100001  0.102680  0.582210  0.200891  0.114219
# 100002  0.077867  0.662646  0.169580  0.089906
# 100003  0.075213  0.585481  0.268254  0.071052
# 100004  0.076064  0.621155  0.192556  0.110225

# %%
submission3.to_csv('xgboost1_submission.csv', header=True)

# %% [markdown]
# That was enough to move me to 409th place with a score of 1.09459. The current numero uno has a score of 1.08497.

# %%
# Tuning parameters
# n_estimators
# early_stopping_rounds
# learning_rate
